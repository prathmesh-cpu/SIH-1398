# %%
import plotly
import pandas as pd
import plotly.express as px
from matplotlib import pyplot as plt

# %%
df1=pd.DataFrame([[19.96,427,'jan1','min'],[16.26,544,'jan2','min'],[14.39,816,'jan3','min'],[13.85,846,'jan4','min'],[14.65,916,'feb1','min'],
                  [11.45,998,'feb2','min'],[11.49,1177,'feb3','min'],[10.20,2756,'feb4','min'],[8.71,3684,'mar1','min'],[8.29,4687,'mar2','min'],
                  [7.86,4499,'mar3','min'],[7.80,8299,'mar4','min'],[8.8,8712,'apr1','min'],[10.65,7253,'apr2','min'],[10.59,7828,'apr3','min'],
                  [10.87,10677,'apr4','min'],[9.94,5365,'may1','min'],[6.89,3528,'may2','min'],[5.87,5295,'may3','min'],[5.10,4815,'may4','min'],
                    [6.05,2065,'jun1','min'],[6.66,2707,'jun2','min'],[6.80,2089,'jun3','min'],[6.18,1551,'jun4','min'],

                  [5.81,679,'jul1','min'],[5.68,682,'jul2','min'],[4.87,924,'jul3','min'],[5.14,1050,'jul4','min'],[6.68,1202,'aug1','min'],
                  [7.84,912,'aug2','min'],[6.44,668,'aug3','min'],[7.16,721,'aug4','min'],[8.22,273,'sept1','min'],[10.56,393,'sept2','min'],
                  [10.85,581,'sept3','min'],[13.61,722,'sept4','min'],[14.79,634,'oct1','min'],[10.30,372,'oct2','min'],[12.84,754,'oct3','min'],
                  [12.77,603,'oct4','min'],[14.31,491,'nov1','min'],[14.05,360,'nov2','min'],[14.65,686,'nov3','min'],[10.92,639,'nov4','min'],
                  [10.47,533,'dec1','min'],[10.99,1605,'dec2','min'],[10.32,1908,'dec3','min'],[7.70,1992,'dec4','min'],

                  [27.20,427,'jan1','max'],[24.12,544,'jan2','max'],[20.83,816,'jan3','max'],[21.09,846,'jan4','max'],[21.04,916,'feb1','max'],
                  [17.02,998,'feb2','max'],[15.55,1177,'feb3','max'],[14.90,2756,'feb4','max'],[14.34,3684,'mar1','max'],[13.75,4687,'mar2','max'],
                  [15.99,4499,'mar3','max'],[14.95,8299,'mar4','max'],[16.03,8712,'apr1','max'],[18.78,7253,'apr2','max'],[17.57,7828,'apr3','max'],
                  [16.57,10677,'apr4','max'],[13.92,5365,'may1','max'],[11.62,3528,'may2','max'],[10.52,5295,'may3','max'],[9.01,4815,'may4','max'],
                  [8.73,2065,'jun1','max'],[10.54,2707,'jun2','max'],[10.92,2089,'jun3','max'],[10.98,1551,'jun4','max'],

                  [10.96,679,'jul1','max'],[11.74,682,'jul2','max'],[10.56,924,'jul3','max'],[9.87,1050,'jul4','max'],[11.83,1202,'aug1','max'],
                  [11.70,912,'aug2','max'],[11.03,668,'aug3','max'],[10.96,721,'aug4','max'],[13.92,273,'sept1','max'],[15.45,393,'sept2','max'],
                  [17.55,581,'sept3','max'],[19.75,722,'sept4','max'],[23.54,634,'oct1','max'],[22.60,372,'oct2','max'],[25.52,754,'oct3','max'],
                  [24.27,603,'oct4','max'],[24.45,491,'nov1','max'],[26.33,360,'nov2','max'],[26.96,686,'nov3','max'],[17.08,639,'nov4','max'],
                  [15.50,533,'dec1','max'],[16.13,1605,'dec2','max'],[14.79,1908,'dec3','max'],[13.67,1992,'dec4','max'] ], columns=["Price","Arrival","Duration","Min/Max"])

# %%
fig1=px.line(df1,x="Duration",y="Price",markers=True,text="Price",color="Min/Max",width=2200,height=500)
fig1.update_traces(textposition="top center",marker_size=10)
fig1.update_layout(title_text="Watermelon Price Trend 2022",title_x=0.5)
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x=df1['Arrival']
y=df1['Duration']
fig2=plt.figure(figsize=(30,7))
plt.bar(y,x)
plt.title('Arrival VS Duration')
plt.show()
